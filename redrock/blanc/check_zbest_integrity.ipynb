# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
filelist = glob.glob('/global/cfs/cdirs/desi/users/rongpu/redux/blanc/single_exposures/*/zbest*.fits')
print(len(filelist))
# Out:
# 3853

# %%
fitsio.read_header(fn)

# %%
for fn in filelist:
    try:
        cat = Table.read(fn, hdu=1)
        print(len(cat), len(cat)==500)
    except:
        print(fn)
# Out:
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# 500 True
# ...

# %% [markdown]
# __Find "error" in the log files__

# %%
filelist = glob.glob('/global/cfs/cdirs/desi/users/rongpu/redux/blanc/single_exposures/*/redrock*.log')
print(len(filelist))
# Out:
# 3853

# %%
for fn in filelist:
    with open(fn, 'r') as f:
        lines = list(map(str.strip, f.readlines()))
    error = False
    for line in lines:
        if line.find('error')!=-1:
            error = True
    if error:
        print(fn, lines[-1])
