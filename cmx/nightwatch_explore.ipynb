# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack
import fitsio
from astropy.io import fits

# %%
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
ls /exposures/nightwatch/20191126/00030152
# Out:
# preproc-b0-00030152-4x.html                 qcframe-z3-00030152.fits
# preproc-b0-00030152.fits                    qcframe-z4-00030152.fits
# preproc-b1-00030152-4x.html                 qcframe-z5-00030152.fits
# preproc-b1-00030152.fits                    qcframe-z7-00030152.fits
# preproc-b2-00030152-4x.html                 qframe-b0-00030152.fits
# preproc-b2-00030152.fits                    qframe-b1-00030152.fits
# preproc-b3-00030152-4x.html                 qframe-b2-00030152.fits
# preproc-b3-00030152.fits                    qframe-b3-00030152.fits
# preproc-b4-00030152-4x.html                 qframe-b4-00030152.fits
# preproc-b4-00030152.fits                    qframe-b5-00030152.fits
# preproc-b5-00030152-4x.html                 qframe-b7-00030152.fits
# preproc-b5-00030152.fits                    qframe-r0-00030152.fits
# preproc-b7-00030152-4x.html                 qframe-r1-00030152.fits
# preproc-b7-00030152.fits                    qframe-r2-00030152.fits
# preproc-r0-00030152-4x.html                 qframe-r3-00030152.fits
# preproc-r0-00030152.fits                    qframe-r4-00030152.fits
# preproc-r1-00030152-4x.html                 qframe-r5-00030152.fits
# preproc-r1-00030152.fits                    qframe-r7-00030152.fits
# preproc-r2-00030152-4x.html                 qframe-z0-00030152.fits
# preproc-r2-00030152.fits                    qframe-z1-00030152.fits
# preproc-r3-00030152-4x.html                 qframe-z2-00030152.fits
# preproc-r3-00030152.fits                    qframe-z3-00030152.fits
# preproc-r4-00030152-4x.html                 qframe-z4-00030152.fits
# preproc-r4-00030152.fits                    qframe-z5-00030152.fits
# preproc-r5-00030152-4x.html                 qframe-z7-00030152.fits
# preproc-r5-00030152.fits                    qproc-b0-00030152.log
# preproc-r7-00030152-4x.html                 qproc-b0-00030152-logfile.html
# preproc-r7-00030152.fits                    qproc-b1-00030152.log
# preproc-z0-00030152-4x.html                 qproc-b1-00030152-logfile.html
# preproc-z0-00030152.fits                    qproc-b2-00030152.log
# preproc-z1-00030152-4x.html                 qproc-b2-00030152-logfile.html
# preproc-z1-00030152.fits                    qproc-b3-00030152.log
# preproc-z2-00030152-4x.html                 qproc-b3-00030152-logfile.html
# preproc-z2-00030152.fits                    qproc-b4-00030152.log
# preproc-z3-00030152-4x.html                 qproc-b4-00030152-logfile.html
# preproc-z3-00030152.fits                    qproc-b5-00030152.log
# preproc-z4-00030152-4x.html                 qproc-b5-00030152-logfile.html
# preproc-z4-00030152.fits                    qproc-b7-00030152.log
# preproc-z5-00030152-4x.html                 qproc-b7-00030152-logfile.html
# preproc-z5-00030152.fits                    qproc-r0-00030152.log
# preproc-z7-00030152-4x.html                 qproc-r0-00030152-logfile.html
# preproc-z7-00030152.fits                    qproc-r1-00030152.log
# psf-b0-00030152.fits                        qproc-r1-00030152-logfile.html
# psf-b1-00030152.fits                        qproc-r2-00030152.log
# psf-b2-00030152.fits                        qproc-r2-00030152-logfile.html
# psf-b3-00030152.fits                        qproc-r3-00030152.log
# psf-b4-00030152.fits                        qproc-r3-00030152-logfile.html
# psf-b5-00030152.fits                        qproc-r4-00030152.log
# psf-b7-00030152.fits                        qproc-r4-00030152-logfile.html
# psf-r0-00030152.fits                        qproc-r5-00030152.log
# psf-r1-00030152.fits                        qproc-r5-00030152-logfile.html
# psf-r2-00030152.fits                        qproc-r7-00030152.log
# psf-r3-00030152.fits                        qproc-r7-00030152-logfile.html
# psf-r4-00030152.fits                        qproc-z0-00030152.log
# psf-r5-00030152.fits                        qproc-z0-00030152-logfile.html
# psf-r7-00030152.fits                        qproc-z1-00030152.log
# psf-z0-00030152.fits                        qproc-z1-00030152-logfile.html
# psf-z1-00030152.fits                        qproc-z2-00030152.log
# psf-z2-00030152.fits                        qproc-z2-00030152-logfile.html
# psf-z3-00030152.fits                        qproc-z3-00030152.log
# psf-z4-00030152.fits                        qproc-z3-00030152-logfile.html
# psf-z5-00030152.fits                        qproc-z4-00030152.log
# psf-z7-00030152.fits                        qproc-z4-00030152-logfile.html
# qa-00030152.fits                            qproc-z5-00030152.log
# qa-amp-00030152.html                        qproc-z5-00030152-logfile.html
# qa-amp-00030152-preproc_table.html          qproc-z7-00030152.log
# qa-camera-00030152.html                     qproc-z7-00030152-logfile.html
# qa-camfiber-00030152-focalplane_plots.html  qsky-b0-00030152.fits
# qa-camfiber-00030152.html                   qsky-b1-00030152.fits
# qa-summary-00030152.html                    qsky-b2-00030152.fits
# qa-summary-00030152-logfiles_table.html     qsky-b3-00030152.fits
# qcframe-b0-00030152.fits                    qsky-b4-00030152.fits
# qcframe-b1-00030152.fits                    qsky-b5-00030152.fits
# qcframe-b2-00030152.fits                    qsky-b7-00030152.fits
# qcframe-b3-00030152.fits                    qsky-r0-00030152.fits
# qcframe-b4-00030152.fits                    qsky-r1-00030152.fits
# qcframe-b5-00030152.fits                    qsky-r2-00030152.fits
# qcframe-b7-00030152.fits                    qsky-r3-00030152.fits
# qcframe-r0-00030152.fits                    qsky-r4-00030152.fits
# qcframe-r1-00030152.fits                    qsky-r5-00030152.fits
# qcframe-r2-00030152.fits                    qsky-r7-00030152.fits
# qcframe-r3-00030152.fits                    qsky-z0-00030152.fits
# qcframe-r4-00030152.fits                    qsky-z1-00030152.fits
# qcframe-r5-00030152.fits                    qsky-z2-00030152.fits
# qcframe-r7-00030152.fits                    qsky-z3-00030152.fits
# qcframe-z0-00030152.fits                    qsky-z4-00030152.fits
# qcframe-z1-00030152.fits                    qsky-z5-00030152.fits
# qcframe-z2-00030152.fits                    qsky-z7-00030152.fits

# %%
hdulist = fits.open('/exposures/nightwatch/20191126/00030152/qcframe-r0-00030152.fits')

# %%
hdulist.info()
# Out:
# Filename: /exposures/nightwatch/20191126/00030152/qcframe-r0-00030152.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  FLUX          1 PrimaryHDU     197   (4128, 500)   float32
#   1  IVAR          1 ImageHDU        10   (4128, 500)   float32
#   2  MASK          1 ImageHDU        12   (4128, 500)   int32 (rescales to uint32)
#   3  YSIGMA        1 ImageHDU        10   (4128, 500)   float32
#   4  WAVELENGTH    1 ImageHDU        11   (4128, 500)   float64
#   5  FIBERMAP      1 BinTableHDU    228   500R x 73C   [K, K, K, K, K, D, D, D, D, K, K, 4A, J, D, K, E, E, E, E, E, I, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 1A, J, K, K, J, K, J, J, J, J, J, 3A, E, E, E, K, B, I, D, D, E, E, E, E, E, E, J, J]

# %%
flux = hdulist[0].data
wl = hdulist[4].data

# %%
fib = 0
plt.figure(figsize=(15, 5))
plt.plot(wl[fib], flux[fib], '-', lw=0.5)
plt.show()
