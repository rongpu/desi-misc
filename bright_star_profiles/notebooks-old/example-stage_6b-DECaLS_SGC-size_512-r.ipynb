# %% [markdown]
# Bulk objects inspection; apply GAIA->LS filter transformation

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, vstack, hstack
import fitsio
import sys, os, glob, time, warnings, gc

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
def plot_cutout(img, pixscale, vmin=-1, vmax=1, unit='arcsec'):
    if unit=='arcsec':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])
    elif unit=='arcmin':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/60.
    elif unit=='deg':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/3600.
    else:
        raise ValueError('unrecognized unit')
    fig, ax = plt.subplots(figsize=(8, 8))
    dens = ax.imshow(img, aspect='equal', 
               cmap='seismic', extent=extent, vmin=vmin, vmax=vmax)
    ax.axvline(0, ls='--', lw=0.5, color='grey')
    ax.axhline(0, ls='--', lw=0.5, color='grey')
    fig.colorbar(dens, fraction=0.046, pad=0.04)
    # plt.grid(alpha=0.5, lw=0.5)
    return ax

def binned_stats(x, y, bins):
    from scipy import stats
    nmad = lambda x: 1.4826*np.median(np.abs(x-np.median(x)))
    bin_median, bin_edges, binnumber = stats.binned_statistic(x, y, statistic='median', bins=bins)
    bin_spread, _, _ = stats.binned_statistic(x, y, statistic=nmad, bins=bins)    
    bin_center = (bin_edges[1:] + bin_edges[:-1])/2
    return bin_center, bin_edges, bin_median, bin_spread

# %% [markdown]
# -------

# %%
# gaia1 and gaia2: DECaLS/DES SGC; gaia3: BASS/MzLS; gaia4: DECaLS NGC
gaia_fn = 'gaia1.fits.gz'
gaia = Table.read('/Users/rongpu/Documents/Data/desi_misc/gaia_from_arjun/'+gaia_fn)
print(len(gaia))

if (gaia_fn=='gaia1.fits.gz') or (gaia_fn=='gaia2.fits.gz'):
    mask = gaia['dec']<31.
    gaia = gaia[mask]
    print(len(gaia))
                                  
if (gaia_fn=='gaia3.fits.gz'):
    mask = gaia['dec']>32.375
    gaia = gaia[mask]
    print(len(gaia))
# Out:
# 603673

# %%
plt.figure(figsize=(10, 5))
plt.plot(gaia['ra'][::10], gaia['dec'][::10], '.', ms=0.1, alpha=0.5)
plt.show()

# %%
# Remove duplicates
if len(np.unique(gaia['source_id']))<len(gaia):
    print('Duplicates exist!')
    gaia.sort('source_id')
    mask = gaia['source_id'][1:]==gaia['source_id'][:-1]
    mask = np.concatenate([[False], mask])
    gaia = gaia[~mask]
    
# Remove objects with invalide mask = np.isfinite(gaia['bp_rp'])
mask = np.isfinite(gaia['bp_rp'])
if np.sum(~mask)>0:
    print('{} objects with invalid bp_rp'.format(np.sum(~mask)))
    gaia = gaia[mask]
# Out:
# 13074 objects with invalid bp_rp

# %%
gaia[:3]
# Out:
# <Table length=3>
#      source_id              ra               ra_error      ...  teff_val a_g_val
#                            deg                 mas         ...     K       mag
#        int64             float64             float64       ...  float32  float32
# ------------------- ------------------ ------------------- ... --------- -------
# 3972839289897271040 175.33439662974035 0.05191210944494655 ... 3987.0999     nan
# 3972709719323995008 174.37060429554896 0.04183941064989952 ... 6066.1196  0.3125
# 3972593720847082368 173.61702739987095 0.07503737420602331 ...    4197.0   1.524

# %%
plt.hist(gaia['phot_g_mean_mag'], 100);

# %%
# Apply GAIA-LS transformation
from scipy.interpolate import interp1d
transform_interp = {}
for band in ['g', 'r', 'z']:
    tmp = np.load('data/gaia_decals_{}_transform.npz'.format(band))
    bin_center, bin_median, bin_spread = tmp['arr_0'], tmp['arr_1'], tmp['arr_2']
    transform_interp[band] = interp1d(bin_center, bin_median, bounds_error=False, fill_value='extrapolate', kind='linear')
    gaia['decals_'+band] = gaia['phot_g_mean_mag'] + transform_interp[band](gaia['bp_rp'])

# %%
plt.hist(gaia['decals_r'], 100);

# %%
# mask = (gaia['phot_g_mean_mag']>16) & ((gaia['phot_g_mean_mag']<18))
# plt.figure(figsize=(8, 8))
# plt.plot((gaia['bp_rp'])[mask], (gaia['decals_g']-gaia['phot_g_mean_mag'])[mask], '.', ms=0.3)
# plt.xlabel('GAIA_BP - GAIA_RP')
# plt.ylabel('DECaLS_G - GAIA_G')
# plt.axis([-0.5, 3.5, -0.5, 3.])
# plt.grid(alpha=0.5)
# plt.show()

# %% [markdown]
# ------
# ## Narrow bin of DECaLS g-band magnitude

# %%
decals_r_min_list = [10.5, 13.0, 15.5]
decals_r_max_list = [10.51, 13.01, 15.51]

# %%
radius_in_bin = []
flux_in_bin = []

for mag_index in range(len(decals_r_min_list)):
        
    decals_r_min, decals_r_max = decals_r_min_list[mag_index], decals_r_max_list[mag_index]
    print('\n', decals_r_min, decals_r_max)
    
    plot_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/plots/04/'    
    band = 'r'
    # img_type = '-resid'
    img_type = ''
    pixscale_str = '0.262'
    pixscale = float(pixscale_str)

    nsamp = 50

    idx = np.where((gaia['decals_r']>decals_r_min) & (gaia['decals_r']<decals_r_max))[0]
    print(len(idx))
    if len(idx)>nsamp:
        np.random.seed(1)
        idx = np.random.choice(idx, size=nsamp, replace=False)
        # print(len(idx))

    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
        
    radius_arr = []
    flux_arr = []

    for index in idx:

        print('phot_g_mean_mag = ', gaia['phot_g_mean_mag'][index])

        ra, dec = gaia['ra'][index], gaia['dec'][index]

        download_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/512/'
        file_path = os.path.join(download_dir, gaia_fn[:-8], 'gaia_{}_{}{}_{}.fits'.format(index, band, img_type, pixscale_str))
        if not os.path.exists(os.path.dirname(file_path)):
            os.makedirs(os.path.dirname(file_path))

        if not os.path.isfile(file_path):
            url = 'http://legacysurvey.org/viewer/cutout.fits?ra={:f}&dec={:f}&layer=dr8{}&pixscale={}&bands={}&size=512'.format(ra, dec, img_type, pixscale_str, band)
            cmd = 'wget -O '+file_path+' \"'+url+'\"'
            print(cmd)
            os.system(cmd)

        img_raw = fitsio.read(file_path)
        img = img_raw / (pixscale**2)

        grid = pixscale * np.linspace(-0.5*(img.shape[0]-1), 0.5*(img.shape[0]-1), img.shape[0])
        xx, yy = np.meshgrid(grid, grid)
        radius = np.sqrt(xx**2 + yy**2).flatten()

        # Remove masked pixels
        mask = img.flatten()!=0
        radius = radius[mask]
        flux = img.flatten()[mask]

        bin_center, _, bin_median, bin_spread = binned_stats(radius, flux, bins=np.linspace(0., 250, 251))
        radius_arr.append(bin_center)
        flux_arr.append(bin_median)

        # vrange = 0.5
        # ax = plot_cutout(img, pixscale, vmin=-vrange, vmax=vrange)
        # ax.set_title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_image.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.plot(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([0, 20, -1, 5])
        # plt.axhline(0, lw=1, color='r')
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.loglog(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([.5, 30, .02, 200])
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile_log.png'))
        # plt.close()

    radius_arr = np.array(radius_arr)
    flux_arr = np.array(flux_arr)
    
    x, _, y, _ = binned_stats(radius_arr.flatten(), flux_arr.flatten(), bins=np.linspace(0., 250, 251))
    radius_in_bin.append(x)
    flux_in_bin.append(y)
# Out:
#  10.5 10.51
# 91
# phot_g_mean_mag =  11.038777
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_351170_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=192.476014&dec=25.066370&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.066004
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_558206_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=170.560146&dec=6.906439&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.739055
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_287655_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=199.782968&dec=10.956717&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.011097
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_339194_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=173.323051&dec=13.707902&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.346687
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_460322_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=178.912307&dec=5.259449&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.692161
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_550456_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=185.287775&dec=28.930176&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.805156
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_356230_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=173.072302&dec=19.184151&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.961295
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_326869_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=175.884565&dec=14.539748&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.127337
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_308441_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=194.465629&dec=10.549102&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.76904
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_258348_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=200.826192&dec=17.322394&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.876372
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_263790_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=202.154876&dec=18.500571&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.035335
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_217522_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=180.591101&dec=3.153053&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.619988
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_445275_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=190.288276&dec=-3.423297&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.7082815
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_191483_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=172.312885&dec=14.812350&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.046606
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_256373_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=187.303432&dec=25.830048&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.667504
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_442601_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=194.943265&dec=27.139979&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.002901
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_95962_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=166.327891&dec=9.427395&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.3080225
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_25462_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=180.467050&dec=-3.048604&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.924216
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_569103_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=180.025273&dec=26.039648&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.864395
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_540149_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=171.624370&dec=22.605852&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.635544
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_327674_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=182.171433&dec=-4.834355&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.599485
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_137277_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=173.471615&dec=18.001569&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.692438
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_549033_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=183.450714&dec=23.467213&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.038408
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_240864_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=199.500837&dec=16.365947&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.0215845
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_229131_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=199.672830&dec=13.904349&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.876394
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_227822_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=166.842413&dec=17.386146&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  11.100035
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_304755_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=193.275540&dec=10.196997&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  10.912618
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_432550_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=182.460574&dec=-0.887439&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =
r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=179.336108&dec=-0.288040&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  15.687255
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_573525_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=188.824545&dec=28.796860&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  15.761406
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_232827_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=171.328079&dec=10.302311&layer=dr8&pixscale=0.262&bands=r&size=512"
# phot_g_mean_mag =  15.775988
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia4/gaia_389057_r_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=193.013382&dec=-6.208579&layer=dr8&pixscale=0.262&bands=r&size=512"
# /Users/rongpu/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/rongpu/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)

# %%
plt.figure(figsize=(12, 8))
for index in range(len(flux_in_bin)):
    # normalize the flux to 13th magnitude stars
    norm = 10**((decals_r_min_list[index]-13)/2.5)
    plt.loglog(radius_in_bin[index], flux_in_bin[index]*norm, lw=1.5, alpha=1., 
               label='{}mag = {:.2f}'.format(band, decals_r_min_list[index]))

x = radius_in_bin[0].copy()
y1 = 1.11 - 4.*(x-1.179)
y2 = -0.4 - 2.5*(x-1.179)
plt.loglog(np.exp(x), np.exp(y1), lw=7, alpha=0.5, color='grey')
plt.loglog(np.exp(x), np.exp(y2), lw=7, alpha=0.5, color='grey')
# plt.loglog(np.exp(x), (np.exp(y1)+np.exp(y2)), lw=7, alpha=0.5, color='red')
plt.title('{}-band flux'.format(band))

plt.axis([.5, 250, .0001, 2000])
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
t = Table()
t['radius'] = radius_in_bin[0]
for index in range(len(flux_in_bin)):
    t['flux_{}_{:.2f}'.format(band, decals_r_min_list[index])] = flux_in_bin[index]
mask = t['radius']>=95.5
t = t[~mask]

t.write('data/DECaLS_SGC_profiles_r.txt', format='ascii.commented_header')

# %%
t
# Out:
# <Table length=95>
#  radius      flux_r_10.50            flux_r_13.00           flux_r_15.50
# float64        float64                 float64                float64
# ------- ---------------------- ----------------------- ---------------------
#     0.5      145.6791763305664      145.67916107177734     74.11619186401367
#     1.5     145.67916870117188       73.57818984985352     5.658930778503418
#     2.5     142.75303649902344       8.175002098083496     0.785057783126831
#     3.5     24.100507736206055      2.3006266355514526    0.2164371982216835
#     4.5      8.538264751434326      0.8868955373764038   0.08991887420415878
#     5.5     3.8440232276916504      0.4152269810438156    0.0420885868370533
#     6.5     1.9492106437683105      0.2257760688662529   0.02352680917829275
#     7.5     1.1413729190826416      0.1382693350315094  0.013282120693475008
#     8.5     0.7610523700714111     0.08838832378387451  0.010173873044550419
#     9.5     0.5599947869777679      0.0645187683403492  0.007571781985461712
#     ...                    ...                     ...                   ...
#    85.5  0.0026117933448404074    0.003501785220578313 0.0016587396967224777
#    86.5  0.0005814570613438264    0.002325197565369308 0.0030190256657078862
#    87.5  0.0012536054709926248   0.0027553908294066787  0.003521479433402419
#    88.5  0.0006834220257587731     0.00208468793425709 0.0027465467574074864
#    89.5  7.098776404745877e-05    0.003765773493796587  0.004215913824737072
#    90.5  0.0005841276633873349 -0.00013596863573184237 0.0031783864833414555
#    91.5  0.0014172723167575896   0.0033641464542597532  0.001764472748618573
#    92.5   0.002669581910595298    0.002052993280813098  0.003996603889390826
#    93.5  0.0024856787640601397  -9.543657506583259e-05   0.00443501234985888
#    94.5 -0.0006895576952956617     0.00722825713455677  0.003677837550640106
