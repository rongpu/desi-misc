# %% [markdown]
# Bulk objects inspection; apply GAIA->LS filter transformation

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, vstack, hstack
import fitsio
import sys, os, glob, time, warnings, gc

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
def plot_cutout(img, pixscale, vmin=-1, vmax=1, unit='arcsec'):
    if unit=='arcsec':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])
    elif unit=='arcmin':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/60.
    elif unit=='deg':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/3600.
    else:
        raise ValueError('unrecognized unit')
    fig, ax = plt.subplots(figsize=(8, 8))
    dens = ax.imshow(img, aspect='equal', 
               cmap='seismic', extent=extent, vmin=vmin, vmax=vmax)
    ax.axvline(0, ls='--', lw=0.5, color='grey')
    ax.axhline(0, ls='--', lw=0.5, color='grey')
    fig.colorbar(dens, fraction=0.046, pad=0.04)
    # plt.grid(alpha=0.5, lw=0.5)
    return ax

def binned_stats(x, y, bins):
    from scipy import stats
    nmad = lambda x: 1.4826*np.median(np.abs(x-np.median(x)))
    bin_median, bin_edges, binnumber = stats.binned_statistic(x, y, statistic='median', bins=bins)
    bin_spread, _, _ = stats.binned_statistic(x, y, statistic=nmad, bins=bins)    
    bin_center = (bin_edges[1:] + bin_edges[:-1])/2
    return bin_center, bin_edges, bin_median, bin_spread

# %% [markdown]
# -------

# %%
# gaia1 and gaia2: DECaLS/DES SGC; gaia3: BASS/MzLS; gaia4: DECaLS NGC
gaia_fn = 'gaia3.fits.gz'
gaia = Table.read('/Users/rongpu/Documents/Data/desi_misc/gaia_from_arjun/'+gaia_fn)
print(len(gaia))

if (gaia_fn=='gaia1.fits.gz') or (gaia_fn=='gaia2.fits.gz'):
    mask = gaia['dec']<31.
    gaia = gaia[mask]
    print(len(gaia))
                                  
if (gaia_fn=='gaia3.fits.gz'):
    mask = gaia['dec']>32.375
    gaia = gaia[mask]
    print(len(gaia))
# Out:
# 568011
# 495651

# %%
plt.figure(figsize=(10, 5))
plt.plot(gaia['ra'][::10], gaia['dec'][::10], '.', ms=0.1, alpha=0.5)
plt.show()

# %%
# Remove duplicates
if len(np.unique(gaia['source_id']))<len(gaia):
    print('Duplicates exist!')
    gaia.sort('source_id')
    mask = gaia['source_id'][1:]==gaia['source_id'][:-1]
    mask = np.concatenate([[False], mask])
    gaia = gaia[~mask]
    
# Remove objects with invalide mask = np.isfinite(gaia['bp_rp'])
mask = np.isfinite(gaia['bp_rp'])
if np.sum(~mask)>0:
    print('{} objects with invalid bp_rp'.format(np.sum(~mask)))
    gaia = gaia[mask]
# Out:
# 5136 objects with invalid bp_rp

# %%
gaia[:3]
# Out:
# <Table length=3>
#     source_id              ra               ra_error      ... teff_val a_g_val
#                           deg                 mas         ...    K       mag
#       int64             float64             float64       ... float32  float32
# ------------------ ------------------ ------------------- ... -------- -------
# 853541947406479744 158.26593562467318 0.03485320287322467 ...   5311.0  0.0827
# 853458659400731264 157.77886322969965 0.03370989785815359 ... 4196.885  0.8823
# 853544593106335616 158.11693668428555 0.03641127032271789 ...   5780.5   0.735

# %%
plt.hist(gaia['phot_g_mean_mag'], 100);

# %%
# Apply GAIA-LS transformation
from scipy.interpolate import interp1d
transform_interp = {}
for band in ['g', 'r', 'z']:
    tmp = np.load('data/gaia_bassmzls_{}_transform.npz'.format(band))
    bin_center, bin_median, bin_spread = tmp['arr_0'], tmp['arr_1'], tmp['arr_2']
    transform_interp[band] = interp1d(bin_center, bin_median, bounds_error=False, fill_value='extrapolate', kind='linear')
    gaia['decals_'+band] = gaia['phot_g_mean_mag'] + transform_interp[band](gaia['bp_rp'])

# %%
plt.hist(gaia['decals_g'], 100);

# %%
mask = (gaia['phot_g_mean_mag']>16) & ((gaia['phot_g_mean_mag']<18))
plt.figure(figsize=(8, 8))
plt.plot((gaia['bp_rp'])[mask], (gaia['decals_g']-gaia['phot_g_mean_mag'])[mask], '.', ms=0.3)
plt.xlabel('GAIA_BP - GAIA_RP')
plt.ylabel('DECaLS_G - GAIA_G')
plt.axis([-0.5, 3.5, -0.5, 3.])
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ------
# ## Narrow bin of DECaLS g-band magnitude

# %%
decals_g_min_list = [10.5, 13.0, 15.5]
decals_g_max_list = [10.51, 13.01, 15.51]

# %%
radius_in_bin = []
flux_in_bin = []

for mag_index in range(len(decals_g_min_list)):
        
    decals_g_min, decals_g_max = decals_g_min_list[mag_index], decals_g_max_list[mag_index]
    print('\n', decals_g_min, decals_g_max)
    
    plot_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/plots/04'    
    band = 'g'
    # img_type = '-resid'
    img_type = ''
    pixscale_str = '0.262'
    pixscale = float(pixscale_str)

    nsamp = 50

    idx = np.where((gaia['decals_g']>decals_g_min) & (gaia['decals_g']<decals_g_max))[0]
    print(len(idx))
    if len(idx)>nsamp:
        np.random.seed(1)
        idx = np.random.choice(idx, size=nsamp, replace=False)
        # print(len(idx))

    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
        
    radius_arr = []
    flux_arr = []

    for index in idx:

        print('phot_g_mean_mag = ', gaia['phot_g_mean_mag'][index])

        ra, dec = gaia['ra'][index], gaia['dec'][index]

        download_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/'
        file_path = os.path.join(download_dir, gaia_fn[:-8], 'gaia_{}_{}{}_{}.fits'.format(index, band, img_type, pixscale_str))
        if not os.path.exists(os.path.dirname(file_path)):
            os.makedirs(os.path.dirname(file_path))

        if not os.path.isfile(file_path):
            url = 'http://legacysurvey.org/viewer/cutout.fits?ra={:f}&dec={:f}&layer=dr8{}&pixscale={}&bands={}'.format(ra, dec, img_type, pixscale_str, band)
            cmd = 'wget -O '+file_path+' \"'+url+'\"'
            print(cmd)
            os.system(cmd)

        img_raw = fitsio.read(file_path)
        img = img_raw / (pixscale**2)

        grid = pixscale * np.linspace(-0.5*(img.shape[0]-1), 0.5*(img.shape[0]-1), img.shape[0])
        xx, yy = np.meshgrid(grid, grid)
        radius = np.sqrt(xx**2 + yy**2).flatten()

        # Remove masked pixels
        mask = img.flatten()!=0
        radius = radius[mask]
        flux = img.flatten()[mask]

        bin_center, _, bin_median, bin_spread = binned_stats(radius, flux, bins=np.linspace(0., 31., 63))
        radius_arr.append(bin_center)
        flux_arr.append(bin_median)

        # vrange = 0.5
        # ax = plot_cutout(img, pixscale, vmin=-vrange, vmax=vrange)
        # ax.set_title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_image.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.plot(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([0, 20, -1, 5])
        # plt.axhline(0, lw=1, color='r')
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.loglog(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([.5, 30, .02, 200])
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile_log.png'))
        # plt.close()

    radius_arr = np.array(radius_arr)
    flux_arr = np.array(flux_arr)
    
    x, _, y, _ = binned_stats(radius_arr.flatten(), flux_arr.flatten(), bins=np.linspace(0., 31., 63))
    radius_in_bin.append(x)
    flux_in_bin.append(y)
# Out:
#  10.5 10.51
# 49
# phot_g_mean_mag =  10.106338
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_438_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=159.127645&dec=56.156413&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.3282175
# phot_g_mean_mag =  9.857304
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_13493_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=171.504246&dec=40.249944&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.251923
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_24324_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=174.917586&dec=42.529042&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.287316
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_24875_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=150.527135&dec=58.164641&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.848373
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_27853_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=175.738058&dec=59.194347&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.854029
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_37322_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=176.546737&dec=62.014015&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.8951845
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_54772_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=162.464461&dec=59.794660&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.738254
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_66132_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=153.162695&dec=59.978015&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.234798
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_79487_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=146.741454&dec=48.388407&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.287227
# phot_g_mean_mag =  9.949762
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_86161_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=163.497810&dec=43.245301&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.288239
# phot_g_mean_mag =  9.336009
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_98382_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=147.772316&dec=52.623684&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.23969
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_102817_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=171.206334&dec=44.250607&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.686574
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_114499_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=173.902256&dec=47.113751&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.088727
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_114580_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=174.134055&dec=47.075226&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.30301
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_123441_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=161.942051&dec=48.887407&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.832565
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_146918_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=151.559228&dec=41.163083&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.8824415
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_151992_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=159.755642&dec=51.073431&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.320412
# phot_g_mean_mag =  10.286509
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_171778_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=155.777952&dec=44.508523&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.555213
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_183746_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=147.497495&dec=42.227566&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.802354
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_218154_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=148.087320&dec=39.565518&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.220578
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_218192_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=148.470190&dec=39.195412&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.935874
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_244607_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=160.760572&dec=36.181069&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.222325
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_285612_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=166.062547&dec=38.531182&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.267492
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_285832_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=165.559070&dec=38.021898&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.243107
# phot_g_mean_mag =  9.918156
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_308009_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=176.745490&dec=33.046907&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.227454
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_309504_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=191.014284&dec=41.520028&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.238671
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_320638_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=195.153317&dec=39.706488&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.209921
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_322007_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=187.222594&dec=53.053110&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.780222
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_324529_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=185.806278&dec=50.890390&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.202591
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_351204_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=197.566729&dec=41.817335&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.229133
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_355044_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=178.111631&dec=39.062891&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  10.247553
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_356231_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=202.015770&dec=44.776138&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.928446
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_358246_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=163.708425&dec=62.975310&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.919902
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia_368074_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=147.381884&dec=55.037655&layer=dr8&pixscale=0.262&bands=g"
# phot_g_mean_mag =  9.894158
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/gaia3/gaia