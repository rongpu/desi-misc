# %% [markdown]
# Bulk objects inspection; apply GAIA->LS filter transformation

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, vstack, hstack
import fitsio
import sys, os, glob, time, warnings, gc

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
def plot_cutout(img, pixscale, vmin=-1, vmax=1, unit='arcsec'):
    if unit=='arcsec':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])
    elif unit=='arcmin':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/60.
    elif unit=='deg':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/3600.
    else:
        raise ValueError('unrecognized unit')
    fig, ax = plt.subplots(figsize=(8, 8))
    dens = ax.imshow(img, aspect='equal', 
               cmap='seismic', extent=extent, vmin=vmin, vmax=vmax)
    ax.axvline(0, ls='--', lw=0.5, color='grey')
    ax.axhline(0, ls='--', lw=0.5, color='grey')
    fig.colorbar(dens, fraction=0.046, pad=0.04)
    # plt.grid(alpha=0.5, lw=0.5)
    return ax

def binned_stats(x, y, bins):
    from scipy import stats
    nmad = lambda x: 1.4826*np.median(np.abs(x-np.median(x)))
    bin_center, bin_median, bin_spread = np.zeros((3, len(bins)-1))
    for index in range(len(bins)-1):
        mask = (x>bins[index]) & (x<bins[index+1])
        bin_center[index] = np.median(x[mask])
        if np.sum(mask)>0:
            bin_median[index] = np.median(y[mask])
            bin_spread[index] = nmad(y[mask])
        else:
            bin_median[index], bin_spread[index] = np.nan, np.nan
    return bin_center, bin_median, bin_spread

# %% [markdown]
# -------

# %%
# gaia1 and gaia2: DECaLS/DES SGC; gaia3: BASS/MzLS; gaia4: DECaLS NGC
gaia_fn = 'gaia3.fits.gz'
gaia = Table.read('/Users/rongpu/Documents/Data/desi_misc/gaia_from_arjun/'+gaia_fn)
print(len(gaia))

if (gaia_fn=='gaia1.fits.gz') or (gaia_fn=='gaia2.fits.gz'):
    mask = gaia['dec']<31.
    gaia = gaia[mask]
    print(len(gaia))
                                  
if (gaia_fn=='gaia3.fits.gz'):
    mask = gaia['dec']>32.375
    gaia = gaia[mask]
    print(len(gaia))
# Out:
# 568011
# 495651

# %%
plt.figure(figsize=(10, 5))
plt.plot(gaia['ra'][::10], gaia['dec'][::10], '.', ms=0.1, alpha=0.5)
plt.show()

# %%
# Remove duplicates
if len(np.unique(gaia['source_id']))<len(gaia):
    print('Duplicates exist!')
    gaia.sort('source_id')
    mask = gaia['source_id'][1:]==gaia['source_id'][:-1]
    mask = np.concatenate([[False], mask])
    gaia = gaia[~mask]
    
# Remove objects with invalide mask = np.isfinite(gaia['bp_rp'])
mask = np.isfinite(gaia['bp_rp'])
if np.sum(~mask)>0:
    print('{} objects with invalid bp_rp'.format(np.sum(~mask)))
    gaia = gaia[mask]
# Out:
# 5136 objects with invalid bp_rp

# %%
gaia[:3]
# Out:
# <Table length=3>
#     source_id              ra               ra_error      ... teff_val a_g_val
#                           deg                 mas         ...    K       mag
#       int64             float64             float64       ... float32  float32
# ------------------ ------------------ ------------------- ... -------- -------
# 853541947406479744 158.26593562467318 0.03485320287322467 ...   5311.0  0.0827
# 853458659400731264 157.77886322969965 0.03370989785815359 ... 4196.885  0.8823
# 853544593106335616 158.11693668428555 0.03641127032271789 ...   5780.5   0.735

# %%
plt.hist(gaia['phot_g_mean_mag'], 100);

# %%
# Apply GAIA-LS transformation
from scipy.interpolate import interp1d
transform_interp = {}
for band in ['g', 'r', 'z']:
    tmp = np.load('data/gaia_bassmzls_{}_transform.npz'.format(band))
    bin_center, bin_median, bin_spread = tmp['arr_0'], tmp['arr_1'], tmp['arr_2']
    transform_interp[band] = interp1d(bin_center, bin_median, bounds_error=False, fill_value='extrapolate', kind='linear')
    gaia['ls_'+band] = gaia['phot_g_mean_mag'] + transform_interp[band](gaia['bp_rp'])

# %% [markdown]
# ------
# ## Narrow bin of DECaLS g-band magnitude

# %%
ls_mag_min_list = [10.5, 13.0, 15.5]
ls_mag_max_list = [10.51, 13.01, 15.51]

# %%
radius_in_bin = []
flux_in_bin = []

for mag_index in range(len(ls_mag_min_list)):
        
    ls_mag_min, ls_mag_max = ls_mag_min_list[mag_index], ls_mag_max_list[mag_index]
    print('\n', '{} < {} < {}'.format(ls_mag_min, band, ls_mag_max))
    
    plot_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/plots/03/'    
    band = 'z'
    # img_type = '-resid'
    img_type = ''
    pixscale_str = '0.262'
    pixscale = float(pixscale_str)

    nsamp = 50

    idx = np.where((gaia['ls_'+band]>ls_mag_min) & (gaia['ls_'+band]<ls_mag_max))[0]
    print(len(idx))
    if len(idx)>nsamp:
        np.random.seed(1)
        idx = np.random.choice(idx, size=nsamp, replace=False)
        # print(len(idx))

    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
        
    radius_arr = []
    flux_arr = []

    for index in idx:

        print('phot_g_mean_mag = ', gaia['phot_g_mean_mag'][index])

        ra, dec = gaia['ra'][index], gaia['dec'][index]

        download_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/512/'
        file_path = os.path.join(download_dir, gaia_fn[:-8], 'gaia_{}_{}{}_{}.fits'.format(index, band, img_type, pixscale_str))
        if not os.path.exists(os.path.dirname(file_path)):
            os.makedirs(os.path.dirname(file_path))

        if not os.path.isfile(file_path):
            url = 'http://legacysurvey.org/viewer/cutout.fits?ra={:f}&dec={:f}&layer=dr8{}&pixscale={}&bands={}&size=512'.format(ra, dec, img_type, pixscale_str, band)
            cmd = 'wget -O '+file_path+' \"'+url+'\"'
            print(cmd)
            os.system(cmd)

        img_raw = fitsio.read(file_path)
        img = img_raw / (pixscale**2)

        grid = pixscale * np.linspace(-0.5*(img.shape[0]-1), 0.5*(img.shape[0]-1), img.shape[0])
        xx, yy = np.meshgrid(grid, grid)
        radius = np.sqrt(xx**2 + yy**2).flatten()
        max_radius = xx.flatten().max() # maximum radius before hitting the edge of the image

        # Remove masked pixels
        mask = img.flatten()!=0
        radius = radius[mask]
        flux = img.flatten()[mask]

        bin_center, bin_median, bin_spread = binned_stats(radius, flux, bins=np.linspace(0., np.floor(max_radius), np.floor(max_radius)+1))
        radius_arr.append(bin_center)
        flux_arr.append(bin_median)

    radius_arr = np.array(radius_arr)
    flux_arr = np.array(flux_arr)
    
    x, y, _ = binned_stats(radius_arr.flatten(), flux_arr.flatten(), bins=np.linspace(0., np.floor(max_radius), np.floor(max_radius)+1))
    radius_in_bin.append(x)
    flux_in_bin.append(y)
# Out:
#  10.5 < z < 10.51
# 99
# phot_g_mean_mag =  10.7630005
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia
z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=164.904853&dec=35.657528&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.012136
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_456797_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=180.411751&dec=62.090453&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.109512
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_29699_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=177.289299&dec=60.610413&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.11535
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_68729_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=166.045096&dec=42.069534&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.222158
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_245459_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=153.960897&dec=33.551035&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.8402405
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_359456_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=183.019103&dec=56.320901&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.874962
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_418199_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=176.046876&dec=34.311848&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.957023
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_203967_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=149.806757&dec=37.496838&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.590647
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_131293_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=151.970673&dec=38.726087&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.9781685
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_477422_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=187.701209&dec=41.799276&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.271378
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_372681_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=159.758563&dec=61.103842&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.964058
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_470671_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=189.470380&dec=41.319070&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.693883
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_365375_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=198.533403&dec=42.812930&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.983699
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_353389_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=187.364616&dec=56.235553&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.489096
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_391885_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=184.492254&dec=34.495586&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.886814
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_467810_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=181.265116&dec=33.252377&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.139633
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_387927_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=191.895407&dec=42.983110&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.717695
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_163702_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=153.070987&dec=40.782526&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.734445
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_16047_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=159.533221&dec=58.650992&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.889192
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_85297_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=161.414635&dec=44.568309&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.275204
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_302826_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=177.038295&dec=39.847243&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.29644
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_475104_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=196.977967&dec=51.497935&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.220512
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_487561_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=183.338006&dec=41.078913&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.817022
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_177344_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=149.605801&dec=41.493201&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.041574
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_281732_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=163.430034&dec=35.560827&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.664877
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_110506_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=176.300665&dec=46.989671&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  15.730232
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_186572_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=168.038698&dec=53.256259&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.972322
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_400391_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=199.724877&dec=47.924242&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.224487
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_186849_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=169.544176&dec=53.525671&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.419937
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_451229_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=185.075801&dec=39.291154&layer=dr8&pixscale=0.262&bands=z&size=512"
# phot_g_mean_mag =  16.4513
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia3/gaia_106052_z_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=173.367259&dec=46.635494&layer=dr8&pixscale=0.262&bands=z&size=512"

# %%
# t = Table()
# t['radius'] = radius_in_bin[0]
# for index in range(len(flux_in_bin)):
#     t['flux_{}_{:.2f}'.format(band, ls_mag_min_list[index])] = flux_in_bin[index]
# mask = t['radius']>=95.5
# t = t[~mask]

# t.write('data/BASSMZLS_profiles_{}.txt'.format(band), format='ascii.commented_header')

# %%
plt.figure(figsize=(12, 8))
for index in range(len(flux_in_bin)):
    # normalize the flux to 13th magnitude stars
    norm = 10**((ls_mag_min_list[index]-13)/2.5)
    plt.loglog(radius_in_bin[index], flux_in_bin[index]*norm, lw=1.5, alpha=1., 
               label='{}mag = {:.2f}'.format(band, ls_mag_min_list[index]))
plt.title('{}-band flux'.format(band))

plt.axis([.5, 250, .0001, 2000])
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
for index in range(len(flux_in_bin)):
    # normalize the flux to 13th magnitude stars
    norm = 10**((ls_mag_min_list[index]-13)/2.5)
    plt.loglog(radius_in_bin[index], flux_in_bin[index]*norm, lw=1.5, alpha=1., 
               label='{}mag = {:.2f}'.format(band, ls_mag_min_list[index]))
plt.title('{}-band flux'.format(band))
plt.axis([.5, 100, .0001, 2000])
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.loglog(radius_arr.T, flux_arr.T, lw=1, alpha=0.3, c='C0')
plt.axis([.5, 30, .001, 200])
plt.grid(alpha=0.5)
# x0, _, y0, _ = binned_stats(radius_arr.flatten(), flux_arr.flatten(), bins=np.linspace(0., 31., 63))
# plt.loglog(x0, y0, lw=4, alpha=0.7, c='C1')
plt.show()
