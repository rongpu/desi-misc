# %% [markdown]
# Bulk objects inspection; apply GAIA->LS filter transformation

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, vstack, hstack
import fitsio
import sys, os, glob, time, warnings, gc

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
def plot_cutout(img, pixscale, vmin=-1, vmax=1, unit='arcsec'):
    if unit=='arcsec':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])
    elif unit=='arcmin':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/60.
    elif unit=='deg':
        extent = 0.5*pixscale*img.shape[0]*np.array([-1, 1, -1, 1])/3600.
    else:
        raise ValueError('unrecognized unit')
    fig, ax = plt.subplots(figsize=(8, 8))
    dens = ax.imshow(img, aspect='equal', 
               cmap='seismic', extent=extent, vmin=vmin, vmax=vmax)
    ax.axvline(0, ls='--', lw=0.5, color='grey')
    ax.axhline(0, ls='--', lw=0.5, color='grey')
    fig.colorbar(dens, fraction=0.046, pad=0.04)
    # plt.grid(alpha=0.5, lw=0.5)
    return ax

def binned_stats(x, y, bins):
    from scipy import stats
    nmad = lambda x: 1.4826*np.median(np.abs(x-np.median(x)))
    bin_median, bin_edges, binnumber = stats.binned_statistic(x, y, statistic='median', bins=bins)
    bin_spread, _, _ = stats.binned_statistic(x, y, statistic=nmad, bins=bins)    
    bin_center = (bin_edges[1:] + bin_edges[:-1])/2
    return bin_center, bin_edges, bin_median, bin_spread

# %% [markdown]
# -------

# %%
# gaia1 and gaia2: DECaLS/DES SGC; gaia3: BASS/MzLS; gaia4: DECaLS NGC
gaia_fn = 'gaia1.fits.gz'
gaia = Table.read('/Users/rongpu/Documents/Data/desi_misc/gaia_from_arjun/'+gaia_fn)
print(len(gaia))

if (gaia_fn=='gaia1.fits.gz') or (gaia_fn=='gaia2.fits.gz'):
    mask = gaia['dec']<31.
    gaia = gaia[mask]
    print(len(gaia))
                                  
if (gaia_fn=='gaia3.fits.gz'):
    mask = gaia['dec']>32.375
    gaia = gaia[mask]
    print(len(gaia))
# Out:
# 855294
# 832837

# %%
plt.figure(figsize=(10, 5))
plt.plot(gaia['ra'][::10], gaia['dec'][::10], '.', ms=0.1, alpha=0.5)
plt.show()

# %%
# Remove duplicates
if len(np.unique(gaia['source_id']))<len(gaia):
    print('Duplicates exist!')
    gaia.sort('source_id')
    mask = gaia['source_id'][1:]==gaia['source_id'][:-1]
    mask = np.concatenate([[False], mask])
    gaia = gaia[~mask]
    
# Remove objects with invalide mask = np.isfinite(gaia['bp_rp'])
mask = np.isfinite(gaia['bp_rp'])
if np.sum(~mask)>0:
    print('{} objects with invalid bp_rp'.format(np.sum(~mask)))
    gaia = gaia[mask]
# Out:
# 5812 objects with invalid bp_rp

# %%
gaia[:3]
# Out:
# <Table length=3>
#     source_id             ra               ra_error       ...  teff_val a_g_val
#                          deg                 mas          ...     K       mag
#       int64            float64             float64        ...  float32  float32
# ----------------- ------------------ -------------------- ... --------- -------
# 76963928454294528 30.405325440623816 0.043583431054268214 ...    5916.0     nan
# 77105250058122496 31.130029533950907   0.0774492987192934 ...    3805.0  0.0298
# 77130912487449088  32.37128459494941  0.07443325440018038 ... 4771.9053  0.3197

# %%
plt.hist(gaia['phot_g_mean_mag'], 100);

# %%
# Apply GAIA-LS transformation
from scipy.interpolate import interp1d
transform_interp = {}
for band in ['g', 'r', 'z']:
    tmp = np.load('data/gaia_decals_{}_transform.npz'.format(band))
    bin_center, bin_median, bin_spread = tmp['arr_0'], tmp['arr_1'], tmp['arr_2']
    transform_interp[band] = interp1d(bin_center, bin_median, bounds_error=False, fill_value='extrapolate', kind='linear')
    gaia['decals_'+band] = gaia['phot_g_mean_mag'] + transform_interp[band](gaia['bp_rp'])

# %%
plt.hist(gaia['decals_g'], 100);

# %%
# mask = (gaia['phot_g_mean_mag']>16) & ((gaia['phot_g_mean_mag']<18))
# plt.figure(figsize=(8, 8))
# plt.plot((gaia['bp_rp'])[mask], (gaia['decals_g']-gaia['phot_g_mean_mag'])[mask], '.', ms=0.3)
# plt.xlabel('GAIA_BP - GAIA_RP')
# plt.ylabel('DECaLS_G - GAIA_G')
# plt.axis([-0.5, 3.5, -0.5, 3.])
# plt.grid(alpha=0.5)
# plt.show()

# %% [markdown]
# ------
# ## Narrow bin of DECaLS g-band magnitude

# %%
decals_g_min_list = [10.5, 13.0, 15.5]
decals_g_max_list = [10.51, 13.01, 15.51]

# %%
radius_in_bin = []
flux_in_bin = []

for mag_index in range(len(decals_g_min_list)):
        
    decals_g_min, decals_g_max = decals_g_min_list[mag_index], decals_g_max_list[mag_index]
    print('\n', decals_g_min, decals_g_max)
    
    plot_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/plots/04/'    
    band = 'g'
    # img_type = '-resid'
    img_type = ''
    pixscale_str = '0.262'
    pixscale = float(pixscale_str)

    nsamp = 50

    idx = np.where((gaia['decals_g']>decals_g_min) & (gaia['decals_g']<decals_g_max))[0]
    print(len(idx))
    if len(idx)>nsamp:
        np.random.seed(1)
        idx = np.random.choice(idx, size=nsamp, replace=False)
        # print(len(idx))

    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
        
    radius_arr = []
    flux_arr = []

    for index in idx:

        print('phot_g_mean_mag = ', gaia['phot_g_mean_mag'][index])

        ra, dec = gaia['ra'][index], gaia['dec'][index]

        download_dir = '/Users/rongpu/Downloads/gaia_star_cutouts/512/'
        file_path = os.path.join(download_dir, gaia_fn[:-8], 'gaia_{}_{}{}_{}.fits'.format(index, band, img_type, pixscale_str))
        if not os.path.exists(os.path.dirname(file_path)):
            os.makedirs(os.path.dirname(file_path))

        if not os.path.isfile(file_path):
            url = 'http://legacysurvey.org/viewer/cutout.fits?ra={:f}&dec={:f}&layer=dr8{}&pixscale={}&bands={}&size=512'.format(ra, dec, img_type, pixscale_str, band)
            cmd = 'wget -O '+file_path+' \"'+url+'\"'
            print(cmd)
            os.system(cmd)

        img_raw = fitsio.read(file_path)
        img = img_raw / (pixscale**2)

        grid = pixscale * np.linspace(-0.5*(img.shape[0]-1), 0.5*(img.shape[0]-1), img.shape[0])
        xx, yy = np.meshgrid(grid, grid)
        radius = np.sqrt(xx**2 + yy**2).flatten()

        # Remove masked pixels
        mask = img.flatten()!=0
        radius = radius[mask]
        flux = img.flatten()[mask]

        bin_center, _, bin_median, bin_spread = binned_stats(radius, flux, bins=np.linspace(0., 250, 251))
        radius_arr.append(bin_center)
        flux_arr.append(bin_median)

        # vrange = 0.5
        # ax = plot_cutout(img, pixscale, vmin=-vrange, vmax=vrange)
        # ax.set_title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_image.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.plot(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([0, 20, -1, 5])
        # plt.axhline(0, lw=1, color='r')
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile.png'))
        # plt.close()

        # plt.figure(figsize=(8, 6))
        # plt.loglog(radius, flux, '.', ms=0.5)
        # plt.plot(bin_center, bin_median, c='C1')
        # plt.errorbar(bin_center, bin_median, yerr=bin_spread, lw=1, alpha=0.6, c='C1')
        # plt.axis([.5, 30, .02, 200])
        # plt.grid(alpha=0.5)
        # plt.title('['+band+'-band]  GAIA_G={:.4f}'.format(gaia['phot_g_mean_mag'][index]))
        # plt.savefig(os.path.join(plot_dir, os.path.basename(file_path)[:-5]+'_profile_log.png'))
        # plt.close()

    radius_arr = np.array(radius_arr)
    flux_arr = np.array(flux_arr)
    
    x, _, y, _ = binned_stats(radius_arr.flatten(), flux_arr.flatten(), bins=np.linspace(0., 250, 251))
    radius_in_bin.append(x)
    flux_in_bin.append(y)
# Out:
#  10.5 10.51
# 76
# phot_g_mean_mag =  8.972918
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_149985_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=8.283779&dec=16.525003&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.245076
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_576756_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=24.390512&dec=29.059314&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  9.592792
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_30848_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=5.050067&dec=17.133160&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  9.807976
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_786671_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=14.532202&dec=0.090670&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  9.781017
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_562779_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=15.022850&dec=29.261423&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.211411
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_242865_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=11.097311&dec=12.590798&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  9.777714
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_362555_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=0.696497&dec=4.650199&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.1428585
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_292412_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=13.912930&dec=17.088740&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.2501335
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_316782_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=8.457271&dec=3.299019&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.232661
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_635771_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=14.213309&dec=22.601962&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  10.255398
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_389933_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=30.741464&dec=11.915020&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  9.021993
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_489250_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra
layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.852554
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_775942_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=353.271149&dec=17.535120&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.913754
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_706124_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=26.456040&dec=18.058083&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.249931
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_811581_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=8.346252&dec=-5.512351&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.094123
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_447772_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=7.418097&dec=29.080662&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.899091
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_55913_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=5.108818&dec=-5.492506&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.967761
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_611996_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=356.949326&dec=5.942634&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.863929
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_682688_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=4.302128&dec=28.491248&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.092452
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_515436_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=13.842767&dec=15.559615&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.914019
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_628874_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=25.341913&dec=-2.843162&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.070803
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_424543_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=21.242855&dec=27.685969&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.087211
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_635247_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=358.203659&dec=27.221641&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.926754
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_159187_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=26.520981&dec=24.104047&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.105842
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_742722_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=28.279806&dec=21.912751&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.395272
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_606651_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=359.941131&dec=1.962198&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.160063
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_125684_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=4.323878&dec=23.191629&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.913513
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_578601_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=29.159791&dec=3.495110&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.084888
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_629526_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=9.672580&dec=24.884625&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.035501
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_23026_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=6.367938&dec=14.078655&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.135974
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_29649_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=11.365839&dec=19.538437&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.076497
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_562642_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=14.632313&dec=29.732498&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.997745
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_516785_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=2.273102&dec=28.899635&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.818916
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_312191_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=8.607287&dec=9.064936&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.1116295
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_386657_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=28.951201&dec=10.788160&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.871113
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_329850_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=12.857993&dec=26.472087&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.025909
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_497984_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=21.883534&dec=30.473215&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.779726
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_396777_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=22.144890&dec=26.724883&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.074335
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_697531_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=28.873447&dec=19.972378&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.969367
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_499762_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=6.101743&dec=16.352478&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  14.67884
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_810923_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=6.240476&dec=16.055562&layer=dr8&pixscale=0.262&bands=g&size=512"
# phot_g_mean_mag =  15.128598
# wget -O /Users/rongpu/Downloads/gaia_star_cutouts/512/gaia1/gaia_108372_g_0.262.fits "http://legacysurvey.org/viewer/cutout.fits?ra=0.002690&dec=11.976458&layer=dr8&pixscale=0.262&bands=g&size=512"
# /Users/rongpu/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/rongpu/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)

# %%
plt.figure(figsize=(12, 8))
for index in range(len(flux_in_bin)):
    # normalize the flux to 13th magnitude stars
    norm = 10**((decals_g_min_list[index]-13)/2.5)
    plt.loglog(radius_in_bin[index], flux_in_bin[index]*norm, lw=1.5, alpha=1., 
               label='{}mag = {:.2f}'.format(band, decals_g_min_list[index]))

x = radius_in_bin[0].copy()
y1 = 1.711 - 4.*(x-1.179)
y2 = 0 - 2.5*(x-1.179)
plt.loglog(np.exp(x), np.exp(y1), lw=7, alpha=0.5, color='grey')
plt.loglog(np.exp(x), np.exp(y2), lw=7, alpha=0.5, color='grey')
# plt.loglog(np.exp(x), (np.exp(y1)+np.exp(y2)), lw=7, alpha=0.5, color='red')
plt.title('{}-band flux'.format(band))

plt.axis([.5, 250, .0001, 2000])
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
t = Table()
t['radius'] = radius_in_bin[0]
for index in range(len(flux_in_bin)):
    t['flux_{}_{:.2f}'.format(band, decals_g_min_list[index])] = flux_in_bin[index]
mask = t['radius']>=95.5
t = t[~mask]

t.write('data/DECaLS_SGC_profiles_g.txt', format='ascii.commented_header')
