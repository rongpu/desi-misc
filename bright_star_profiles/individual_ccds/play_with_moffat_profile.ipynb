# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np

# %%
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
from scipy.optimize import curve_fit

def get_frac_moffat(r, alpha, beta):
    """
    Calculate the fraction of light within radius r of a Moffat profile.
    """    
    frac = 1 - alpha**(2*(beta-1))*(alpha**2 + r**2)**(1-beta)
    return(frac)

def get_sb_moffat(r, alpha, beta):
    """
    Calculate the surface brightness of light at radius r of a Moffat profile.
    The integral (i.e., total flux) is unity by definition.
    """
    i = (beta-1)/(np.pi * alpha**2)*(1 + (r/alpha)**2)**(-beta)
    return i

# %%
beta = 3.
x = np.linspace(0, 10, 1000)

plt.figure(figsize=(8, 6))
for alpha in [1., 2., 4.]:
    plt.plot(x, get_sb_moffat(x, alpha, beta)/np.max(get_sb_moffat(x, alpha, beta)), label=r'$\alpha$={:.2f}  $\beta$={:.2f}'.format(alpha, beta))
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
beta = 3.
x = np.logspace(-1, 1., 1000)

plt.figure(figsize=(8, 6))
for alpha in [1., 2., 4.]:
    plt.loglog(x, get_sb_moffat(x, alpha, beta)/np.max(get_sb_moffat(x, alpha, beta)), label=r'$\alpha$={:.2f}  $\beta$={:.2f}'.format(alpha, beta))
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# __Fix beta__

# %%
alpha = 2.
x = np.linspace(0, 10, 1000)

plt.figure(figsize=(8, 6))
for beta in [1.5, 3, 6]:
    plt.plot(x, get_sb_moffat(x, alpha, beta)/np.max(get_sb_moffat(x, alpha, beta)), label=r'$\alpha$={:.2f}  $\beta$={:.2f}'.format(alpha, beta))
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# %%
alpha = 2.
x = np.logspace(-1, 1., 1000)

plt.figure(figsize=(8, 6))
for beta in [1.5, 3, 6]:
    plt.loglog(x, get_sb_moffat(x, alpha, beta)/np.max(get_sb_moffat(x, alpha, beta)), label=r'$\alpha$={:.2f}  $\beta$={:.2f}'.format(alpha, beta))
plt.grid(alpha=0.5)
plt.legend()
plt.show()
