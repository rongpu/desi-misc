# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
cat = Table.read('/Users/rongpu/Documents/Data/dr9_tests/outliers/coadd_stats.fits')

# %%
mask = np.ones(len(cat), dtype=bool)
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=1, alpha=1)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

# %%
mask = cat['npix_case1_z']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case1_z'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.123247665950604 30006

# %%
mask = cat['npix_case1_z']>0
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

mask = cat['npix_case1_z']>10
print(np.sum(mask))
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 60

# %%
mask = cat['npix_case2_z']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case2_z'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.16665913637091773 40575

# %%
mask = cat['npix_case2_z']>1
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

mask = cat['npix_case2_z']>10**1
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 6052
# 229

# %%
mask = cat['npix_case3_z']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case3_z'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()

plt.hist(np.log10(cat['npix_case3_z'][mask]), 100, range=(0, 1), log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.0016717256562652745 407

# %%
mask = cat['npix_case3_z']>10
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 317

# %%
idx = np.where(mask)[0]
print(len(idx))
if len(idx)>200:
    idx = np.random.choice(idx, size=200, replace=False)
t = Table()
t['RA'] = cat['RA'][idx]
t['DEC'] = cat['DEC'][idx]
t.write('/Users/rongpu/Downloads/visual_inspection_z.txt', format='ascii.no_header', overwrite=True)
# Out:
# 317
