# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
cat = Table.read('/Users/rongpu/Documents/Data/dr9_tests/outliers/coadd_stats.fits')

# %%
mask = np.ones(len(cat), dtype=bool)
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=1, alpha=1)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

# %%
mask = cat['npix_case1_g']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case1_g'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.1604404812269727 39061

# %%
mask = cat['npix_case1_g']>0
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

mask = cat['npix_case1_g']>10
print(np.sum(mask))
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 49

# %%
mask = cat['npix_case2_g']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case2_g'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()

plt.hist(np.log10(cat['npix_case2_g'][mask]), 100, range=(2.5, 3.5), log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.9905282570925117 241155

# %%
mask = cat['npix_case2_g']>10**2
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()

mask = cat['npix_case2_g']>10**2.9
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 62707
# 150

# %%
mask = cat['npix_case3_g']>0
print(np.sum(mask)/len(mask), np.sum(mask))

plt.hist(np.log10(cat['npix_case3_g'][mask]), 100, log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()

plt.hist(np.log10(cat['npix_case3_g'][mask]), 100, range=(0, 1), log=True)
plt.xlabel('log10(n_bad_pix)')
plt.show()
# Out:
# 0.07676794229876653 18690

# %%
mask = cat['npix_case3_g']>0
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()


mask = cat['npix_case3_g']>1e3
print(np.sum(mask))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1)
ax.plot(cat['RA'][mask], cat['DEC'][mask], '.', ms=10, alpha=.5)
plt.axis([360, 0, -70, 40])
ax.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig('/Users/rongpu/Downloads/corrupt/r.png')
plt.show()
# Out:
# 18690
# 110

# %%
idx = np.where(mask)[0]
print(len(idx))
if len(idx)>200:
    idx = np.random.choice(idx, size=200, replace=False)
t = Table()
t['RA'] = cat['RA'][idx]
t['DEC'] = cat['DEC'][idx]
t.write('/Users/rongpu/Downloads/visual_inspection_g.txt', format='ascii.no_header', overwrite=True)
# Out:
# 110
