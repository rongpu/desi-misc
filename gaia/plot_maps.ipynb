# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

sys.path.append(os.path.expanduser('~/git/desi-examples/imaging_systematics'))
from plot_healpix_map import plot_map

# %%
params = {'legend.fontsize': 'large',
          'axes.labelsize': 'large',
          'axes.titlesize': 'large',
          'xtick.labelsize': 'large',
          'ytick.labelsize': 'large',
          'figure.facecolor': 'w'}
plt.rcParams.update(params)

# %%
m = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_density_map_256.fits'))

plot_map(256, m['HPXPIXEL'], np.array(m['N_GAIA']).astype(float), dpi=1200, xsize=6000, cmap='gray_r',
         save_path='plots/gaia_xp_density_256.png', vmin=0, vmax=200)
# Out:
# Done! 00:01:00

# %%
m = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_dr9_offset_maps_256.fits'))

for band in ['g', 'r', 'z']:
    mask = np.isfinite(m[band+'mag_diff'])
    plot_map(256, m['HPXPIXEL'][mask], m[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='seismic',
             vmin=-0.04, vmax=0.04,
             save_path='plots/gaia_xp_dr9_offset_{}_256.png'.format(band))
# Out:
# Done! 00:00:59
# Done! 00:00:59
# Done! 00:00:59
