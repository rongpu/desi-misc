# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

sys.path.append(os.path.expanduser('~/git/desi-examples/imaging_systematics'))
from plot_healpix_map import plot_map

# %%
params = {'legend.fontsize': 'large',
          'axes.labelsize': 'large',
          'axes.titlesize': 'large',
          'xtick.labelsize': 'large',
          'ytick.labelsize': 'large',
          'figure.facecolor': 'w'}
plt.rcParams.update(params)

# %%
density = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_density_map_256.fits'))

plot_map(256, density['HPXPIXEL'], np.array(density['N_GAIA']).astype(float), dpi=1200, xsize=6000, cmap='gray_r',
         save_path='plots/gaia_xp_density_256.png', vmin=0, vmax=200)
# Out:
# Done! 00:01:00

# %% [markdown]
# ----------
# ## DR9 South

# %%
dr9_south_offsets = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_dr9_south_offset_maps_256.fits'))

# %%
for band in ['g', 'r', 'z']:
    plot_map(256, dr9_south_offsets['HPXPIXEL'], np.array(dr9_south_offsets[band+'mag_n_objects']).astype(float), dpi=1200, xsize=6000, cmap='gray_r',
         save_path='plots/gaia_xp_dr9_south_density_{}_256.png'.format(band), vmin=0, vmax=200)
# Out:
# Done! 00:00:59
# Done! 00:00:59
# Done! 00:00:59

# %%
for band in ['g', 'r', 'z']:
    mask = np.isfinite(dr9_south_offsets[band+'mag_diff'])
    plot_map(256, dr9_south_offsets['HPXPIXEL'][mask], dr9_south_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='seismic',
             vmin=-0.04, vmax=0.04,
             save_path='plots/gaia_xp_dr9_south_offset_{}_256.png'.format(band))
# Out:
# Done! 00:00:59
# Done! 00:00:59
# Done! 00:00:59

# %%
for band in ['g', 'r', 'z']:
    mask = np.isfinite(dr9_south_offsets[band+'mag_diff'])
    plot_map(256, dr9_south_offsets['HPXPIXEL'][mask], dr9_south_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='gray',
             vmin=-0.03, vmax=0.03,
             save_path='plots/gaia_xp_dr9_south_offset_{}_256_gray.png'.format(band))
# Out:
# Done! 00:01:00
# Done! 00:00:58

# %% [markdown]
# ----------
# ## DR9 North

# %%
dr9_north_offsets = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_dr9_north_offset_maps_256.fits'))

for band in ['g', 'r', 'z']:
    plot_map(256, dr9_north_offsets['HPXPIXEL'], np.array(dr9_north_offsets[band+'mag_n_objects']).astype(float), dpi=1200, xsize=6000, cmap='gray_r',
         save_path='plots/gaia_xp_dr9_north_density_{}_256.png'.format(band), vmin=0, vmax=200)

for band in ['g', 'r', 'z']:
    mask = np.isfinite(dr9_north_offsets[band+'mag_diff'])
    plot_map(256, dr9_north_offsets['HPXPIXEL'][mask], dr9_north_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='seismic',
             vmin=-0.04, vmax=0.04,
             save_path='plots/gaia_xp_dr9_north_offset_{}_256.png'.format(band))

for band in ['g', 'r', 'z']:
    mask = np.isfinite(dr9_north_offsets[band+'mag_diff'])
    plot_map(256, dr9_north_offsets['HPXPIXEL'][mask], dr9_north_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='gray',
             vmin=-0.03, vmax=0.03,
             save_path='plots/gaia_xp_dr9_north_offset_{}_256_gray.png'.format(band))
# Out:
# Done! 00:00:59
# Done! 00:00:59
# Done! 00:00:58
# Done! 00:00:58
# Done! 00:00:59
# Done! 00:00:58
# Done! 00:00:58
# Done! 00:00:58
# Done! 00:00:58

# %% [markdown]
# --------
# ## DR10

# %%
dr10_offsets = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/data/gaia_dr3/misc/gaia_xp_dr10_offset_maps_256.fits'))

for band in ['g', 'r', 'i', 'z']:
    plot_map(256, dr10_offsets['HPXPIXEL'], np.array(dr10_offsets[band+'mag_n_objects']).astype(float), dpi=1200, xsize=6000, cmap='gray_r',
             save_path='plots/gaia_xp_dr10_density_{}_256.png'.format(band), vmin=0, vmax=200)

for band in ['g', 'r', 'i', 'z']:
    mask = np.isfinite(dr10_offsets[band+'mag_diff'])
    plot_map(256, dr10_offsets['HPXPIXEL'][mask], dr10_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='seismic',
             vmin=-0.04, vmax=0.04,
             save_path='plots/gaia_xp_dr10_offset_{}_256.png'.format(band))

for band in ['g', 'r', 'i', 'z']:
    mask = np.isfinite(dr10_offsets[band+'mag_diff'])
    plot_map(256, dr10_offsets['HPXPIXEL'][mask], dr10_offsets[band+'mag_diff'][mask], dpi=1200, xsize=6000, cmap='gray',
             vmin=-0.03, vmax=0.03,
             save_path='plots/gaia_xp_dr10_offset_{}_256_gray.png'.format(band))
