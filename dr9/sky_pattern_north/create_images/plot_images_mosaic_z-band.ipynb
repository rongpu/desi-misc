# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, vstack, hstack
import fitsio
from astropy.io import fits
import healpy as hp
from astropy import wcs

from scipy.ndimage.filters import gaussian_filter

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
ccdnum_list = [1, 2, 3, 4]
ccd_ra = [0.1554, 0.1554, -0.1554, -0.1554]
ccd_dec = [0.1554, -0.1554, 0.1554, -0.1554]

# %%
plot_dir = '/global/project/projectdirs/desi/www/users/rongpu/plots/dr9dev/mosaic_images/'
image_dir = '/global/cfs/cdirs/cosmo/staging/'
band = 'z'

dr9 = Table.read('/global/project/projectdirs/cosmo/work/legacysurvey/dr9/survey-ccds-mosaic-dr9.fits.gz')
dr8 = Table.read('/global/cfs/cdirs/cosmo/work/legacysurvey/dr9-garage/reorg/mosaic/survey-ccds-mosaic-dr8-newlocs.fits.gz')

mask = dr9['ccd_cuts']==0
mask &= dr9['filter']==band
dr9 = dr9[mask]
print(len(dr9))

mask = dr8['ccd_cuts']==0
mask &= dr8['filter']==band
dr8 = dr8[mask]
print(len(dr8))
# Out:
# 208308
# 206834

# %%
# Require all 4 CCDs
expnum, count = np.unique(dr9['expnum'], return_counts=True)
mask = count==4
mask = np.in1d(dr9['expnum'], expnum[mask])
print(np.sum(mask)/len(mask))
dr9 = dr9[mask]
expnum, count = np.unique(dr8['expnum'], return_counts=True)
mask = count==4
mask = np.in1d(dr8['expnum'], expnum[mask])
print(np.sum(mask)/len(mask))
dr8 = dr8[mask]

# Keep only overlapping exposures
mask = np.in1d(dr9['expnum'], dr8['expnum'])
print(np.sum(mask)/len(mask))
dr9 = dr9[mask]

mask = np.in1d(dr8['expnum'], dr9['expnum'])
print(np.sum(mask)/len(mask))
dr8 = dr8[mask]

print(len(dr8), len(dr9))
# Out:
# 0.990494844173
# 0.987555237533
# 0.965356131984
# 0.97512973661
# 199180 199180

# %%
index = 0
image_path = os.path.join(image_dir, dr9['image_filename'][index].strip())
print(os.path.isfile(image_path), image_path)

image_path_dr8 = os.path.join(image_dir, dr8['image_filename'][index].strip())
print(os.path.isfile(image_path_dr8), image_path_dr8)
# Out:
# True /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160228/k4m_160229_041132_ooi_zd_ls9.fits.fz
# True /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160205/k4m_160206_032412_ooi_zd_v2.fits.fz

# %%
expnum_list = np.unique(dr9['expnum'])
np.random.seed(123)
expnum_list = np.random.choice(expnum_list, size=20, replace=False)

# %%
vrange = 0.4
binsize = 2
pix_size = 0.262/3600*binsize

for index, expnum in enumerate(expnum_list[:20]):
    
    print('expnum:', expnum)

    # Find an arbitrary CCD in the exposure to get the image filename
    ccd_index_dr8 = np.where((dr8['expnum']==expnum))[0][0]
    ccd_index_dr9 = np.where((dr9['expnum']==expnum))[0][0]

    image_path_dr9fg = os.path.join(image_dir, dr9['image_filename'][ccd_index_dr9].strip())
    image_path_dr8 = os.path.join(image_dir, dr8['image_filename'][ccd_index_dr8].strip().replace('90prime/BOK_CP/', '90prime/CP/'+dr8['plver'][ccd_index_dr9]+'/'))
    # if 'NonDECaLS-DR8' in dr8['image_filename'][ccd_index_dr8]:
    #     # image_path_dr8 = '/global/projecta/projectdirs/cosmo/staging/' + dr8['image_filename'][ccd_index_dr8].strip()
    #     print('skip NonDECaLS')
    #     continue
    
    if not os.path.isfile(image_path_dr8):
        print('Not found:', image_path_dr8)
        print(dr8['image_filename'][ccd_index_dr8])
        continue
    
    print(image_path_dr8)
    print(image_path_dr9fg)

    ############################## dr9 images ##############################

    plt.figure(figsize=(14, 14))

    for ii, ccdnum in enumerate(ccdnum_list):
        
        try:
            img = fits.getdata(image_path_dr9fg, extname='CCD'+str(ccdnum))
        except:
            print('Failure loading {}'.format(image_path_dr9fg))
            continue
            
        ################ downsize image ################

        # trim edges to enable downsizing
        # trimmed image size need to be multiples of binsize
        trim_size_x = img.shape[1] % binsize
        trim_size_y = img.shape[0] % binsize
        img = img[:(img.shape[0]-trim_size_y), :(img.shape[1]-trim_size_x)]
        # print(img.shape)

        # to ignore NAN values, use np.nanmean
        img = np.mean(np.mean(img.reshape((img.shape[0]//binsize, binsize, img.shape[1]//binsize,-1)), axis=3), axis=1)

        ################################################

        ysize, xsize = img.shape        
        ra, dec = ccd_ra[ii], ccd_dec[ii]

        # naive sky estimation
        mask = (img<np.percentile(img.flatten(), 95))
        median_sky = np.median(img[mask].flatten())
        
        img = img - median_sky
        img[~np.isfinite(img)] = 0
        img = gaussian_filter(img, 3, mode='reflect', truncate=3)
        fig = plt.imshow(img.T, cmap='seismic', vmin=-vrange, vmax=vrange, 
                   extent=(ra-ysize*pix_size/2, ra+ysize*pix_size/2, dec-xsize*pix_size/2, dec+xsize*pix_size/2))

    plt.axis([0.3, -0.3, -0.3, 0.3])
    plt.axis('off')
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
    plt.colorbar(fraction=0.04, pad=0.04)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, os.path.basename(image_path_dr9fg).replace('.fits.fz', '.png')))
    if index==0:
        plt.show()
    plt.close()

    ############################## DR8 images ##############################
    
    plt.figure(figsize=(14, 14))

    for ii, ccdnum in enumerate(ccdnum_list):
        
        try:
            img = fits.getdata(image_path_dr8, extname='CCD'+str(ccdnum))
        except:
            print('Failure loading {}'.format(image_path_dr8))
            continue

        ################ downsize image ################

        # trim edges to enable downsizing
        # trimmed image size need to be multiples of binsize
        trim_size_x = img.shape[1] % binsize
        trim_size_y = img.shape[0] % binsize
        img = img[:(img.shape[0]-trim_size_y), :(img.shape[1]-trim_size_x)]
        # print(img.shape)

        # to ignore NAN values, use np.nanmean
        img = np.mean(np.mean(img.reshape((img.shape[0]//binsize, binsize, img.shape[1]//binsize,-1)), axis=3), axis=1)

        ################################################

        ysize, xsize = img.shape        
        ra, dec = ccd_ra[ii], ccd_dec[ii]

        # naive sky estimation
        mask = (img<np.percentile(img.flatten(), 95))
        median_sky = np.median(img[mask].flatten())
        
        img = img - median_sky
        img[~np.isfinite(img)] = 0
        img = gaussian_filter(img, 3, mode='reflect', truncate=3)
        fig = plt.imshow(img.T, cmap='seismic', vmin=-vrange, vmax=vrange, 
                   extent=(ra-ysize*pix_size/2, ra+ysize*pix_size/2, dec-xsize*pix_size/2, dec+xsize*pix_size/2))

    plt.axis([0.3, -0.3, -0.3, 0.3])
    plt.axis('off')
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
    plt.colorbar(fraction=0.04, pad=0.04)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, os.path.basename(image_path_dr8).replace('.fits.fz', '.png')))
    if index==0:
        plt.show()
    plt.close()
# Out:
# expnum: 160826
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.2/CP20180205/k4m_180206_111437_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20180205/k4m_180206_111437_ooi_zd_ls9.fits.fz
# expnum: 86229
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160430/k4m_160501_101609_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160430/k4m_160501_101609_ooi_zd_ls9.fits.fz
# expnum: 128554
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170517/k4m_170518_033329_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170517/k4m_170518_033329_ooi_zd_ls9.fits.fz
# expnum: 84992
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160425/k4m_160426_053535_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160425/k4m_160426_053535_ooi_zd_ls9.fits.fz
# expnum: 3106282
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170202/k4m_170203_033009_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170202/k4m_170203_033009_ooi_zd_ls9.fits.fz
# expnum: 127604
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170511/k4m_170512_063439_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170511/k4m_170512_063439_ooi_zd_ls9.fits.fz
# expnum: 161612
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.2/CP20180209/k4m_180210_090835_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20180209/k4m_180210_090835_ooi_zd_ls9.fits.fz
# expnum: 67822
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160210/k4m_160211_024525_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160210/k4m_160211_024525_ooi_zd_ls9.fits.fz
# expnum: 146306
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20171112/k4m_171113_113855_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20171112/k4m_171113_113855_ooi_zd_ls9.fits.fz
# expnum: 89033
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160513/k4m_160514_080309_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160513/k4m_160514_080309_ooi_zd_ls9.fits.fz
# expnum: 151122103931
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20151121/k4m_151122_103931_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20151121/k4m_151122_103931_ooi_zd_ls9.fits.fz
# expnum: 101593
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20161214/k4m_161215_084719_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20161214/k4m_161215_084719_ooi_zd_ls9.fits.fz
# expnum: 93561
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160604/k4m_160605_102014_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160604/k4m_160605_102014_ooi_zd_ls9.fits.fz
# expnum: 76170
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160314/k4m_160315_050109_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160314/k4m_160315_050109_ooi_zd_ls9.fits.fz
# expnum: 127366
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170510/k4m_170511_073311_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170510/k4m_170511_073311_ooi_zd_ls9.fits.fz
# expnum: 159506
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20180131/k4m_180201_083048_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20180131/k4m_180201_083048_ooi_zd_ls9.fits.fz
# expnum: 81035
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160403/k4m_160404_081950_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160403/k4m_160404_081950_ooi_zd_ls9.fits.fz
# expnum: 3106365
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170202/k4m_170203_073229_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170202/k4m_170203_073229_ooi_zd_ls9.fits.fz
# expnum: 76582
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.0/CP20160315/k4m_160316_061618_ooi_zd_v2.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20160315/k4m_160316_061618_ooi_zd_ls9.fits.fz
# expnum: 141697
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.1/CP20170930/k4m_171001_114847_ooi_zd_v1.fits.fz
# /global/cfs/cdirs/cosmo/staging/mosaic/CP/V4.3/CP20170930/k4m_171001_114847_ooi_zd_ls9.fits.fz
